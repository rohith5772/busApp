# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
# Send a GET request to the URL
filename = 'bus_routes.csv'

newstr=""
with open(filename, 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
        x = row[0].replace(' ', '')
        y = row[1]
        z = row[2]
        print(x)
        print(row[1])
        print(row[2])
# Out:
# ['Bus Number', 'Source', 'Destination']
# BusNumber
# Source
# Destination
# ['1', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
# 1
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['', 'Secunderabad Junction', 'Go to Page 2 »']
#
# Secunderabad Junction
# Go to Page 2 »
# ['1E\n', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
# 1E
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['', 'Tukaram Gate', 'Go to Page 2 »']
#
# Tukaram Gate
# Go to Page 2 »
# ['1K\n', 'Koti Bus Stop', 'Go to Page 2 »']
# 1K
#
# Koti Bus Stop
# Go to Page 2 »
# ['', 'Secunderabad Junction', 'Go to Page 2 »']
#
# Secunderabad Junction
# Go to Page 2 »
# ['1L\n', 'LB Nagar Bus Stop', 'Go to Page 2 »']
# 1L
#
# LB Nagar Bus Stop
# Go to Page 2 »
# ['', 'Secunderabad Junction', 'Go to Page 2 »']
#
# Secunderabad Junction
# Go to Page 2 »
# ['1P\n', 'Secunderabad Junction', 'Go to Page 2 »']
# 1P
#
# Secunderabad Junction
# Go to Page 2 »
# ['', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['1V/229\n', 'NGOs Colony Bus Stop', 'Go to Page 2 »']
# 1V/229
#
# NGOs Colony Bus Stop
# Go to Page 2 »
# ['', 'Medchal', 'Go to Page 2 »']
#
# Medchal
# Go to Page 2 »
# ['1/94R\n', 'Secunderabad Junction', 'Go to Page 2 »']
# 1/94R
#
# Secunderabad Junction
# Go to Page 2 »
# ['', 'Rajendra Nagar Bus Depot Bus Stop', 'Go to Page 2 »']
#
# Rajendra Nagar Bus Depot Bus Stop
# Go to Page 2 »
# ['1HD\n', 'Dilsukhnagar Bus station', 'Go to Page 2 »']
# 1HD
#
# Dilsukhnagar Bus station
# Go to Page 2 »
# ['', 'Secunderabad Junction', 'Go to Page 2 »']
#
# Secunderabad Junction
# Go to Page 2 »
# ['1MD\n', 'New Maruthi Nagar', 'Go to Page 2 »']
# 1MD
#
# New Maruthi Nagar
# Go to Page 2 »
# ['', 'Secunderabad Junction', 'Go to Page 2 »']
#
# Secunderabad Junction
# Go to Page 2 »
# ['1R\n', 'Lakdikapool Bus Stop', 'Go to Page 2 »']
# 1R
#
# Lakdikapool Bus Stop
# Go to Page 2 »
# ['', 'Tolichowki Bus Stop', 'Go to Page 2 »']
#
# Tolichowki Bus Stop
# Go to Page 2 »
# ['1/229\n', 'Medchal', 'Go to Page 2 »']
# 1/229
#
# Medchal
# Go to Page 2 »
# ['', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['2C\n', 'Barkas', 'Go to Page 2 »']
# 2C
#
# Barkas
# Go to Page 2 »
# ['', 'Secunderabad Junction', 'Go to Page 2 »']
#
# Secunderabad Junction
# Go to Page 2 »
# ['2J\n', 'Secunderabad Junction', 'Go to Page 2 »']
# 2J
#
# Secunderabad Junction
# Go to Page 2 »
# ['', 'Ziaguda', 'Go to Page 2 »']
#
# Ziaguda
# Go to Page 2 »
# ['2V\n', 'Secunderabad Junction', 'Go to Page 2 »']
# 2V
#
# Secunderabad Junction
# Go to Page 2 »
# ['', 'Charminar Bus Stop', 'Go to Page 2 »']
#
# Charminar Bus Stop
# Go to Page 2 »
# ['3\n', 'Kushaiguda', 'Go to Page 2 »']
# 3
#
# Kushaiguda
# Go to Page 2 »
# ['', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['3B\n', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
# 3B
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['', 'NGRI 1st Gate', 'Go to Page 2 »']
#
# NGRI 1st Gate
# Go to Page 2 »
# ['3CL\n', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
# 3CL
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['', 'Lalapet', 'Go to Page 2 »']
#
# Lalapet
# Go to Page 2 »
# ['3E\n', 'Yapral Bus Stop', 'Go to Page 2 »']
# 3E
#
# Yapral Bus Stop
# Go to Page 2 »
# ['', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['3H\n', 'ECIL Bus Stop', 'Go to Page 2 »']
# 3H
#
# ECIL Bus Stop
# Go to Page 2 »
# ['', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['3I\n', 'CBS Bus Stop', 'Go to Page 2 »']
# 3I
#
# CBS Bus Stop
# Go to Page 2 »
# ['', 'Moula Ali', 'Go to Page 2 »']
#
# Moula Ali
# Go to Page 2 »
# ['1B\n', 'Afzalgunj Bus Stop', 'Go to Page 2 »']
# 1B
#
# Afzalgunj Bus Stop
# Go to Page 2 »
# ['', 'JBS Bus Stop', 'Go to Page 2 »']
#
# JBS Bus Stop
# Go to Page 2 »
# ['1i\n', 'Secunderabad Junction', 'Go to Page 2 »']
# 1i
#
# Secunderabad Junction
# Go to Page 2 »
# ['', 'MGBS Bus Stop', 'Go to Page 2 »']
#
# MGBS Bus Stop
# Go to Page 2 »
# ['1K/229\n', 'Koti Bus Stop', 'Go to Page 2 »']
# 1K/229
#
# Koti Bus Stop
# Go to Page 2 »
# ['', 'Medchal', 'Go to Page 2 »']
#
# Medchal
# Go to Page 2 »
# ['1H\n', 'Secunderabad Junction', 'Go to Page 2 »']
# 1H
#
# Secunderabad Junction
# Go to Page 2 »
# ['', 'Rajendra Nagar Bus Depot Bus Stop', 'Go to Page 2 »']
#
# Rajendra Nagar Bus Depot Bus Stop
# Go to Page 2 »
# ['1V\n', 'NGOs Colony Bus Stop', '']
# 1V
#
# NGOs Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['1Y\n', 'Secunderabad Junction', '']
# 1Y
#
# Secunderabad Junction
#
# ['', 'Zoo Park', '']
#
# Zoo Park
#
# ['1K/25\n', 'Koti Bus Stop', '']
# 1K/25
#
# Koti Bus Stop
#
# ['', 'Old Alwal(IG Statue) Bus Stop', '']
#
# Old Alwal(IG Statue) Bus Stop
#
# ['1J\n', 'Ziaguda', '']
# 1J
#
# Ziaguda
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['1P/25I\n', 'Koti Bus Stop', '']
# 1P/25I
#
# Koti Bus Stop
#
# ['', 'Old Alwal(IG Statue) Bus Stop', '']
#
# Old Alwal(IG Statue) Bus Stop
#
# ['1F/38S\n', 'Falaknuma', '']
# 1F/38S
#
# Falaknuma
#
# ['', 'Safilguda Bus Stop', '']
#
# Safilguda Bus Stop
#
# ['2\n', 'Secunderabad Junction', '']
# 2
#
# Secunderabad Junction
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['2D\n', 'MB Darga', '']
# 2D
#
# MB Darga
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['2U\n', 'Secunderabad Junction', '']
# 2U
#
# Secunderabad Junction
#
# ['', 'Uppuguda', '']
#
# Uppuguda
#
# ['2Z\n', 'Secunderabad Junction', '']
# 2Z
#
# Secunderabad Junction
#
# ['', 'Madhuban colony', '']
#
# Madhuban colony
#
# ['3A\n', 'Koti Bus Stop', '']
# 3A
#
# Koti Bus Stop
#
# ['', 'Chilkanagar Bus Stop', '']
#
# Chilkanagar Bus Stop
#
# ['3C\n', 'Afzalgunj Bus Stop', '']
# 3C
#
# Afzalgunj Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['3D\n', 'Dammaiguda(lake)', '']
# 3D
#
# Dammaiguda(lake)
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['3G\n', 'Gokhle Nagar', '']
# 3G
#
# Gokhle Nagar
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['3H/95A\n', 'NFC(ECIL)', '']
# 3H/95A
#
# NFC(ECIL)
#
# ['', 'Acharya N G Ranga Agricultural University', '']
#
# Acharya N G Ranga Agricultural University
#
# ['3JJ\n', 'Ambedkar Nagar(Kapra)', '']
# 3JJ
#
# Ambedkar Nagar(Kapra)
#
# ['', 'MGBS Bus Stop', '']
#
# MGBS Bus Stop
#
# ['3K\n', 'Kushaiguda', '']
# 3K
#
# Kushaiguda
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['3N\n', 'Afzalgunj Bus Stop', '']
# 3N
#
# Afzalgunj Bus Stop
#
# ['', 'Hema Nagar', '']
#
# Hema Nagar
#
# ['3R\n', 'Koti Bus Stop', '']
# 3R
#
# Koti Bus Stop
#
# ['', 'NGRI 1st Gate', '']
#
# NGRI 1st Gate
#
# ['3SS\n', 'Koti Bus Stop', '']
# 3SS
#
# Koti Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['3Z\n', 'Kushaiguda', '']
# 3Z
#
# Kushaiguda
#
# ['', 'Zoo Park', '']
#
# Zoo Park
#
# ['3H/242\n', 'Keesara guta', '']
# 3H/242
#
# Keesara guta
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['3/242RG\n', 'Rajiv Gruhakalpa Colony', '']
# 3/242RG
#
# Rajiv Gruhakalpa Colony
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['4\n', 'Afzalgunj Bus Stop', '']
# 4
#
# Afzalgunj Bus Stop
#
# ['', 'Kushaiguda', '']
#
# Kushaiguda
#
# ['5B\n', 'Bapu Ghat', '']
# 5B
#
# Bapu Ghat
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5GP\n', 'GPRA QTRS', '']
# 5GP
#
# GPRA QTRS
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5BK\n', 'Bapu Ghat', '']
# 5BK
#
# Bapu Ghat
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5L\n', 'Secunderabad Junction', '']
# 5L
#
# Secunderabad Junction
#
# ['', 'Langar House Bus Stop', '']
#
# Langar House Bus Stop
#
# ['5MD\n', 'Secunderabad Junction', '']
# 5MD
#
# Secunderabad Junction
#
# ['', 'Moti Darwaza', '']
#
# Moti Darwaza
#
# ['5PK\n', 'Puppalaguda', '']
# 5PK
#
# Puppalaguda
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5S\n', 'Sanikpuri Bus Stop', '']
# 5S
#
# Sanikpuri Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['5SK\n', 'Shaikpet Darga Bus Stop', '']
# 5SK
#
# Shaikpet Darga Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5/229\n', 'Medchal', '']
# 5/229
#
# Medchal
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['5K/120\n', 'Secunderabad Junction', '']
# 5K/120
#
# Secunderabad Junction
#
# ['', 'Osman sagar Road', '']
#
# Osman sagar Road
#
# ['5K/250\n', 'Mehdipatnam Bus Stop', '']
# 5K/250
#
# Mehdipatnam Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['6\n', 'VST Bus Stop', '']
# 6
#
# VST Bus Stop
#
# ['', 'Tolichowki Bus Stop', '']
#
# Tolichowki Bus Stop
#
# ['3M\n', 'Afzalgunj Bus Stop', '']
# 3M
#
# Afzalgunj Bus Stop
#
# ['', 'A.S.Rao Nagar Bus Stop', '']
#
# A.S.Rao Nagar Bus Stop
#
# ['3P\n', 'Yapral Bus Stop', '']
# 3P
#
# Yapral Bus Stop
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['3S\n', 'Kachiguda Bus Stop', '']
# 3S
#
# Kachiguda Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['3Y\n', 'Vampuguda', '']
# 3Y
#
# Vampuguda
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['3HN\n', 'Afzalgunj Bus Stop', '']
# 3HN
#
# Afzalgunj Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['3KL\n', 'Afzalgunj Bus Stop', '']
# 3KL
#
# Afzalgunj Bus Stop
#
# ['', 'KLR Nagar', '']
#
# KLR Nagar
#
# ['3KJ\n', 'Kushaiguda', '']
# 3KJ
#
# Kushaiguda
#
# ['', 'Ziaguda', '']
#
# Ziaguda
#
# ['5\n', 'Secunderabad Junction', '']
# 5
#
# Secunderabad Junction
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['5C\n', 'Secunderabad Junction', '']
# 5C
#
# Secunderabad Junction
#
# ['', 'Tolichowki Bus Stop', '']
#
# Tolichowki Bus Stop
#
# ['5K\n', 'Mehdipatnam Bus Stop', '']
# 5K
#
# Mehdipatnam Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5BL\n', 'Bapu Ghat', '']
# 5BL
#
# Bapu Ghat
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5M\n', 'Secunderabad Junction', '']
# 5M
#
# Secunderabad Junction
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['5P\n', 'Puppalaguda', '']
# 5P
#
# Puppalaguda
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5R\n', 'Risala Bazar', '']
# 5R
#
# Risala Bazar
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['5SD\n', 'Mehdipatnam Bus Stop', '']
# 5SD
#
# Mehdipatnam Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5T\n', 'Risala Bazar', '']
# 5T
#
# Risala Bazar
#
# ['', 'Tallagada', '']
#
# Tallagada
#
# ['5G\n', 'Golkonda Bus Stop', '']
# 5G
#
# Golkonda Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5K/188\n', 'Kalimandir', '']
# 5K/188
#
# Kalimandir
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['5TR\n', 'Risala Bazar', '']
# 5TR
#
# Risala Bazar
#
# ['', 'Tallagada', '']
#
# Tallagada
#
# ['6C\n', 'VST Bus Stop', '']
# 6C
#
# VST Bus Stop
#
# ['', 'Gachibowli Bus Station', '']
#
# Gachibowli Bus Station
#
# ['6H\n', 'Mehdipatnam Bus Stop', '']
# 6H
#
# Mehdipatnam Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['6K\n', 'Kushaiguda', '']
# 6K
#
# Kushaiguda
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['6M\n', 'Mehdipatnam Bus Stop', '']
# 6M
#
# Mehdipatnam Bus Stop
#
# ['', 'Railway Quarters Moulali', '']
#
# Railway Quarters Moulali
#
# ['6G\n', 'Gangaputra Colony Bus Stop', '']
# 6G
#
# Gangaputra Colony Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['6B\n', 'Ram Nagar', '']
# 6B
#
# Ram Nagar
#
# ['', 'Ocean Park(Water Park)', '']
#
# Ocean Park(Water Park)
#
# ['7I\n', 'Secunderabad Junction', '']
# 7I
#
# Secunderabad Junction
#
# ['', 'MGBS Bus Stop', '']
#
# MGBS Bus Stop
#
# ['7V\n', 'Venkatapuram Last Bus Stop', '']
# 7V
#
# Venkatapuram Last Bus Stop
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['7K/229\n', 'Medchal', '']
# 7K/229
#
# Medchal
#
# ['', 'MGBS Bus Stop', '']
#
# MGBS Bus Stop
#
# ['8C\n', 'Secunderabad Junction', '']
# 8C
#
# Secunderabad Junction
#
# ['', 'Falaknuma', '']
#
# Falaknuma
#
# ['8M\n', 'Secunderabad Junction', '']
# 8M
#
# Secunderabad Junction
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['8R\n', 'Risala Bazar', '']
# 8R
#
# Risala Bazar
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['8RZ\n', 'Risala Bazar', '']
# 8RZ
#
# Risala Bazar
#
# ['', 'Zoo Park', '']
#
# Zoo Park
#
# ['8V\n', 'NGOs Colony Bus Stop', '']
# 8V
#
# NGOs Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['8C/229\n', 'Medchal', '']
# 8C/229
#
# Medchal
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['9A\n', 'Sri Ram Nagar(Chintal)', '']
# 9A
#
# Sri Ram Nagar(Chintal)
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['9C\n', 'Yousufguda basti Bus Stop', '']
# 9C
#
# Yousufguda basti Bus Stop
#
# ['', 'MGBS Bus Stop', '']
#
# MGBS Bus Stop
#
# ['9F\n', 'Borabanda Bus Stop', '']
# 9F
#
# Borabanda Bus Stop
#
# ['', 'Falaknuma', '']
#
# Falaknuma
#
# ['9G\n', 'Rajeev Nagar', '']
# 9G
#
# Rajeev Nagar
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['9J/84S\n', 'Peddamma Gudi', '']
# 9J/84S
#
# Peddamma Gudi
#
# ['', 'Saroor Nagar Bus Terminal', '']
#
# Saroor Nagar Bus Terminal
#
# ['9K/102\n', 'Lab Quarters Main Bus Stop', '']
# 9K/102
#
# Lab Quarters Main Bus Stop
#
# ['', 'Chintal Bus station', '']
#
# Chintal Bus station
#
# ['6J\n', 'VST Bus Stop', '']
# 6J
#
# VST Bus Stop
#
# ['', 'Jubilee Hills', '']
#
# Jubilee Hills
#
# ['6S\n', 'Secunderabad Junction', '']
# 6S
#
# Secunderabad Junction
#
# ['', 'Langar House Bus Stop', '']
#
# Langar House Bus Stop
#
# ['6T\n', 'Tallagada', '']
# 6T
#
# Tallagada
#
# ['', 'VST Bus Stop', '']
#
# VST Bus Stop
#
# ['6R\n', 'Ram Nagar', '']
# 6R
#
# Ram Nagar
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['7C\n', 'Secunderabad Junction', '']
# 7C
#
# Secunderabad Junction
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['7M\n', 'MGBS Bus Stop', '']
# 7M
#
# MGBS Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['7Z\n', 'Secunderabad Junction', '']
# 7Z
#
# Secunderabad Junction
#
# ['', 'Zoo Park', '']
#
# Zoo Park
#
# ['8A\n', 'Secunderabad Junction', '']
# 8A
#
# Secunderabad Junction
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['8DB\n', 'Doodh Bowli', '']
# 8DB
#
# Doodh Bowli
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['8M/251\n', 'Shamshabad Bus Stop', '']
# 8M/251
#
# Shamshabad Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['8S\n', 'Secunderabad Junction', '']
# 8S
#
# Secunderabad Junction
#
# ['', 'Tolichowki Bus Stop', '']
#
# Tolichowki Bus Stop
#
# ['8U\n', 'Uppuguda', '']
# 8U
#
# Uppuguda
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['8/229\n', 'Medchal', '']
# 8/229
#
# Medchal
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['9\n', 'Jeedimetla Bus Stop', '']
# 9
#
# Jeedimetla Bus Stop
#
# ['', 'MGBS Bus Stop', '']
#
# MGBS Bus Stop
#
# ['9B\n', 'Sanath Nagar Bus Stop', '']
# 9B
#
# Sanath Nagar Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['9E\n', 'Subhash Nagar(Jeedimetla)', '']
# 9E
#
# Subhash Nagar(Jeedimetla)
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['9FE\n', 'Borabanda Bus Stop', '']
# 9FE
#
# Borabanda Bus Stop
#
# ['', 'ESI Bus Stop', '']
#
# ESI Bus Stop
#
# ['9J\n', 'Koti Bus Stop', '']
# 9J
#
# Koti Bus Stop
#
# ['', 'Kondapur Bus Stop', '']
#
# Kondapur Bus Stop
#
# ['9K\n', 'Jeedimetla Bus Stop', '']
# 9K
#
# Jeedimetla Bus Stop
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['9K/227\n', 'Charminar Bus Stop', '']
# 9K/227
#
# Charminar Bus Stop
#
# ['', 'Bahadurpally', '']
#
# Bahadurpally
#
# ['9M\n', 'Falaknuma', '']
# 9M
#
# Falaknuma
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['9N\n', 'Charminar Bus Stop', '']
# 9N
#
# Charminar Bus Stop
#
# ['', 'Uday Nagar', '']
#
# Uday Nagar
#
# ['9R\n', 'A G Colony', '']
# 9R
#
# A G Colony
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['9X\n', 'Jeedimetla Bus Stop', '']
# 9X
#
# Jeedimetla Bus Stop
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['9YF\n', 'Borabanda Bus Stop', '']
# 9YF
#
# Borabanda Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['9YH\n', 'Gayatri Hills', '']
# 9YH
#
# Gayatri Hills
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['9BM\n', 'Falaknuma', '']
# 9BM
#
# Falaknuma
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['9SF\n', 'Borabanda Bus Stop', '']
# 9SF
#
# Borabanda Bus Stop
#
# ['', 'Falaknuma', '']
#
# Falaknuma
#
# ['10\n', 'Secunderabad Junction', '']
# 10
#
# Secunderabad Junction
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['10B\n', 'Secunderabad Junction', '']
# 10B
#
# Secunderabad Junction
#
# ['', 'Bharat Nagar(Moosapet) Bus Stop', '']
#
# Bharat Nagar(Moosapet) Bus Stop
#
# ['10H\n', 'Secunderabad Junction', '']
# 10H
#
# Secunderabad Junction
#
# ['', 'Kondapur Bus Stop', '']
#
# Kondapur Bus Stop
#
# ['10K\n', 'KPHB Colony Bus Stop', '']
# 10K
#
# KPHB Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10J\n', 'Lalaguda Bus Stop', '']
# 10J
#
# Lalaguda Bus Stop
#
# ['', 'JNTU(Kukatpally) Bus Stop', '']
#
# JNTU(Kukatpally) Bus Stop
#
# ['10N\n', 'Secunderabad Junction', '']
# 10N
#
# Secunderabad Junction
#
# ['', 'Nandi Nagar Bus Stop', '']
#
# Nandi Nagar Bus Stop
#
# ['10R\n', 'Secunderabad Junction', '']
# 10R
#
# Secunderabad Junction
#
# ['', 'Rahmath Nagar Bus Stop', '']
#
# Rahmath Nagar Bus Stop
#
# ['10Y\n', 'Secunderabad Junction', '']
# 10Y
#
# Secunderabad Junction
#
# ['', 'Yousufguda basti Bus Stop', '']
#
# Yousufguda basti Bus Stop
#
# ['10YH\n', 'Gayatri Hills', '']
# 10YH
#
# Gayatri Hills
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10KP\n', 'Pragathi Nagar Bus Stop', '']
# 10KP
#
# Pragathi Nagar Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10FY\n', 'Borabanda Bus Stop', '']
# 10FY
#
# Borabanda Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['9ML\n', 'Charminar Bus Stop', '']
# 9ML
#
# Charminar Bus Stop
#
# ['', 'HAL Colony', '']
#
# HAL Colony
#
# ['9D\n', 'Jeedimetla Bus Stop', '']
# 9D
#
# Jeedimetla Bus Stop
#
# ['', 'MGBS Bus Stop', '']
#
# MGBS Bus Stop
#
# ['9Q\n', 'Suchitra Bus Stop', '']
# 9Q
#
# Suchitra Bus Stop
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['9V\n', 'Gayatri Hills', '']
# 9V
#
# Gayatri Hills
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['9Y\n', 'Yousufguda basti Bus Stop', '']
# 9Y
#
# Yousufguda basti Bus Stop
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['9YG\n', 'Karmika Nagar', '']
# 9YG
#
# Karmika Nagar
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['9Z\n', 'Nampally', '']
# 9Z
#
# Nampally
#
# ['', 'Balanagar Bus Stop', '']
#
# Balanagar Bus Stop
#
# ['9GF\n', 'Borabanda Bus Stop', '']
# 9GF
#
# Borabanda Bus Stop
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['9KB\n', 'Balanagar Bus Stop', '']
# 9KB
#
# Balanagar Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['10AS\n', 'Allwyn Colony Bus Stop', '']
# 10AS
#
# Allwyn Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10F\n', 'Borabanda Bus Stop', '']
# 10F
#
# Borabanda Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10KJ\n', 'Jagadgiri Gutta Bus Stop', '']
# 10KJ
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10KL\n', 'KPHB IVth phase', '']
# 10KL
#
# KPHB IVth phase
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10L\n', 'Secunderabad Junction', '']
# 10L
#
# Secunderabad Junction
#
# ['', 'KPHB IVth phase', '']
#
# KPHB IVth phase
#
# ['10PF\n', 'Secunderabad Junction', '']
# 10PF
#
# Secunderabad Junction
#
# ['', 'Borabanda Bus Stop', '']
#
# Borabanda Bus Stop
#
# ['10U\n', 'Uppal Bus Stop', '']
# 10U
#
# Uppal Bus Stop
#
# ['', 'Jubilee Hills', '']
#
# Jubilee Hills
#
# ['10YF\n', 'Borabanda Bus Stop', '']
# 10YF
#
# Borabanda Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['10BK\n', 'Secunderabad Junction', '']
# 10BK
#
# Secunderabad Junction
#
# ['', 'Uday Nagar', '']
#
# Uday Nagar
#
# ['10KV\n', 'Secunderabad Junction', '']
# 10KV
#
# Secunderabad Junction
#
# ['', 'Miyapur Bus Stop', '']
#
# Miyapur Bus Stop
#
# ['10H/17H\n', 'Kondapur Bus Stop', '']
# 10H/17H
#
# Kondapur Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['11\n', 'VBIT(Ascendas IT Park)', '']
# 11
#
# VBIT(Ascendas IT Park)
#
# ['', 'ESI Bus Stop', '']
#
# ESI Bus Stop
#
# ['11N\n', 'Nampally', '']
# 11N
#
# Nampally
#
# ['', 'Gandhi Bhavan Bus Stop', '']
#
# Gandhi Bhavan Bus Stop
#
# ['14\n', 'Secunderabad Junction', '']
# 14
#
# Secunderabad Junction
#
# ['', 'Lalapet', '']
#
# Lalapet
#
# ['15\n', 'Kushaiguda', '']
# 15
#
# Kushaiguda
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['15H\n', 'ECIL Bus Stop', '']
# 15H
#
# ECIL Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['15IG\n', 'Secunderabad Junction', '']
# 15IG
#
# Secunderabad Junction
#
# ['', 'Indira Gruhakalph Colony', '']
#
# Indira Gruhakalph Colony
#
# ['16A/5N\n', 'ECIL Bus Stop', '']
# 16A/5N
#
# ECIL Bus Stop
#
# ['', 'NTR Stadium Bus Stop', '']
#
# NTR Stadium Bus Stop
#
# ['16E\n', 'Secunderabad Junction', '']
# 16E
#
# Secunderabad Junction
#
# ['', 'Moula Ali', '']
#
# Moula Ali
#
# ['16ES\n', 'Moula Ali', '']
# 16ES
#
# Moula Ali
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['16H/47L\n', 'ECIL Bus Stop', '']
# 16H/47L
#
# ECIL Bus Stop
#
# ['', 'Film Nagar', '']
#
# Film Nagar
#
# ['16AK\n', 'Secunderabad Junction', '']
# 16AK
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['16R\n', 'Secunderabad Junction', '']
# 16R
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['16T\n', 'Sanikpuri Bus Stop', '']
# 16T
#
# Sanikpuri Bus Stop
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['16A/242\n', 'Secunderabad Junction', '']
# 16A/242
#
# Secunderabad Junction
#
# ['', 'Keesara guta', '']
#
# Keesara guta
#
# ['16AS\n', 'ECIL Bus Stop', '']
# 16AS
#
# ECIL Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['16NY\n', 'Secunderabad Junction', '']
# 16NY
#
# Secunderabad Junction
#
# ['', 'Yapral Bus Stop', '']
#
# Yapral Bus Stop
#
# ['17\n', 'Kushaiguda', '']
# 17
#
# Kushaiguda
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['17H/229\n', 'Kushaiguda', '']
# 17H/229
#
# Kushaiguda
#
# ['', 'Medchal', '']
#
# Medchal
#
# ['17HN\n', 'Secunderabad Junction', '']
# 17HN
#
# Secunderabad Junction
#
# ['', 'Kushaiguda', '']
#
# Kushaiguda
#
# ['17DN/10K\n', 'KPHB Colony Bus Stop', '']
# 17DN/10K
#
# KPHB Colony Bus Stop
#
# ['', 'Ambedkar Nagar(Kapra)', '']
#
# Ambedkar Nagar(Kapra)
#
# ['11M\n', 'Nampally', '']
# 11M
#
# Nampally
#
# ['', 'Nizam College', '']
#
# Nizam College
#
# ['12\n', 'Ram Nagar', '']
# 12
#
# Ram Nagar
#
# ['', 'VBIT(Ascendas IT Park)', '']
#
# VBIT(Ascendas IT Park)
#
# ['14P\n', 'Prasanth Nagar(Moula Ali)', '']
# 14P
#
# Prasanth Nagar(Moula Ali)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['15D\n', 'Ambedkar Nagar(Kapra)', '']
# 15D
#
# Ambedkar Nagar(Kapra)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['15H/242RG\n', 'Rajiv Gruhakalpa Colony', '']
# 15H/242RG
#
# Rajiv Gruhakalpa Colony
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['16A\n', 'Secunderabad Junction', '']
# 16A
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['16C\n', 'Secunderabad Junction', '']
# 16C
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['16A/102\n', 'ECIL Bus Stop', '']
# 16A/102
#
# ECIL Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['16H\n', 'Secunderabad Junction', '']
# 16H
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['16KP\n', 'Neredmet X Road Bus Stop', '']
# 16KP
#
# Neredmet X Road Bus Stop
#
# ['', 'Dilsukhnagar Bus station', '']
#
# Dilsukhnagar Bus station
#
# ['16P\n', 'Secunderabad Junction', '']
# 16P
#
# Secunderabad Junction
#
# ['', 'Prasanth Nagar(Moula Ali)', '']
#
# Prasanth Nagar(Moula Ali)
#
# ['16RK\n', 'Secunderabad Junction', '']
# 16RK
#
# Secunderabad Junction
#
# ['', 'Ramakrishna Puram Railway Station', '']
#
# Ramakrishna Puram Railway Station
#
# ['16A/10F\n', 'ECIL Bus Stop', '']
# 16A/10F
#
# ECIL Bus Stop
#
# ['', 'Borabanda Bus Stop', '']
#
# Borabanda Bus Stop
#
# ['16A/49M\n', 'ECIL Bus Stop', '']
# 16A/49M
#
# ECIL Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['16H/10H\n', 'ECIL Bus Stop', '']
# 16H/10H
#
# ECIL Bus Stop
#
# ['', 'Kondapur Bus Stop', '']
#
# Kondapur Bus Stop
#
# ['16V\n', 'Secunderabad Junction', '']
# 16V
#
# Secunderabad Junction
#
# ['', 'Vampuguda', '']
#
# Vampuguda
#
# ['17D\n', 'Ambedkar Nagar(Kapra)', '']
# 17D
#
# Ambedkar Nagar(Kapra)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['17HN/47L\n', 'ECIL Bus Stop', '']
# 17HN/47L
#
# ECIL Bus Stop
#
# ['', 'Film Nagar', '']
#
# Film Nagar
#
# ['17/226\n', 'ECIL Bus Stop', '']
# 17/226
#
# ECIL Bus Stop
#
# ['', 'Lingampally Bus Stop', '']
#
# Lingampally Bus Stop
#
# ['17JJ\n', 'Secunderabad Junction', '']
# 17JJ
#
# Secunderabad Junction
#
# ['', 'Ambedkar Nagar(Kapra)', '']
#
# Ambedkar Nagar(Kapra)
#
# ['17S\n', 'Secunderabad Junction', '']
# 17S
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['17SS\n', 'Secunderabad Junction', '']
# 17SS
#
# Secunderabad Junction
#
# ['', 'Saket(Kapra)', '']
#
# Saket(Kapra)
#
# ['17H/226C\n', 'ECIL Bus Stop', '']
# 17H/226C
#
# ECIL Bus Stop
#
# ['', 'BHEL', '']
#
# BHEL
#
# ['17H/10I\n', 'ECIL Bus Stop', '']
# 17H/10I
#
# ECIL Bus Stop
#
# ['', 'KPHB IVth phase', '']
#
# KPHB IVth phase
#
# ['18B\n', 'Secunderabad Junction', '']
# 18B
#
# Secunderabad Junction
#
# ['', 'Boduppal', '']
#
# Boduppal
#
# ['18R\n', 'Secunderabad Junction', '']
# 18R
#
# Secunderabad Junction
#
# ['', 'RTC Colony (Ramanthapur)', '']
#
# RTC Colony (Ramanthapur)
#
# ['18/10L\n', 'Uppal Bus Stop', '']
# 18/10L
#
# Uppal Bus Stop
#
# ['', 'KPHB IVth phase', '']
#
# KPHB IVth phase
#
# ['19KS\n', 'Mehdipatnam Bus Stop', '']
# 19KS
#
# Mehdipatnam Bus Stop
#
# ['', 'Kukatpally Bus Stop', '']
#
# Kukatpally Bus Stop
#
# ['19M\n', 'KPHB IVth phase', '']
# 19M
#
# KPHB IVth phase
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['19FS\n', 'Borabanda Bus Stop', '']
# 19FS
#
# Borabanda Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['19KJ\n', 'Jagadgiri Gutta Bus Stop', '']
# 19KJ
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['20M\n', 'Secunderabad Junction', '']
# 20M
#
# Secunderabad Junction
#
# ['', 'Vijaya Nagar Colony Bus Stop(New Mallepally)', '']
#
# Vijaya Nagar Colony Bus Stop(New Mallepally)
#
# ['20V\n', 'Secunderabad Junction', '']
# 20V
#
# Secunderabad Junction
#
# ['', 'Vijaya Nagar Colony Bus Stop(New Mallepally)', '']
#
# Vijaya Nagar Colony Bus Stop(New Mallepally)
#
# ['21\n', 'Secunderabad Junction', '']
# 21
#
# Secunderabad Junction
#
# ['', 'Venkatapuram Last Bus Stop', '']
#
# Venkatapuram Last Bus Stop
#
# ['21W\n', 'Secunderabad Junction', '']
# 21W
#
# Secunderabad Junction
#
# ['', 'West Venkatapuram Last Bus Stop', '']
#
# West Venkatapuram Last Bus Stop
#
# ['22\n', 'Risala Bazar', '']
# 22
#
# Risala Bazar
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['22D\n', 'Secunderabad Junction', '']
# 22D
#
# Secunderabad Junction
#
# ['', 'MB Darga', '']
#
# MB Darga
#
# ['22K\n', 'Secunderabad Junction', '']
# 22K
#
# Secunderabad Junction
#
# ['', 'Bharat Nagar(Moosapet) Bus Stop', '']
#
# Bharat Nagar(Moosapet) Bus Stop
#
# ['22R\n', 'Secunderabad Junction', '']
# 22R
#
# Secunderabad Junction
#
# ['', 'Risala Bazar', '']
#
# Risala Bazar
#
# ['22/102\n', 'Risala Bazar', '']
# 22/102
#
# Risala Bazar
#
# ['', 'Kesav Giri', '']
#
# Kesav Giri
#
# ['17CS\n', 'Secunderabad Junction', '']
# 17CS
#
# Secunderabad Junction
#
# ['', 'Cherlapally Bus Stop', '']
#
# Cherlapally Bus Stop
#
# ['17H\n', 'ECIL Bus Stop', '']
# 17H
#
# ECIL Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['17H/10H\n', 'ECIL Bus Stop', '']
# 17H/10H
#
# ECIL Bus Stop
#
# ['', 'Kondapur Bus Stop', '']
#
# Kondapur Bus Stop
#
# ['18\n', 'Secunderabad Junction', '']
# 18
#
# Secunderabad Junction
#
# ['', 'Uppal Depot', '']
#
# Uppal Depot
#
# ['18C\n', 'Secunderabad Junction', '']
# 18C
#
# Secunderabad Junction
#
# ['', 'Chengi Cherla', '']
#
# Chengi Cherla
#
# ['18V\n', 'Secunderabad Junction', '']
# 18V
#
# Secunderabad Junction
#
# ['', 'Venkata Reddy Nagar Bus Stop', '']
#
# Venkata Reddy Nagar Bus Stop
#
# ['18L\n', 'Secunderabad Junction', '']
# 18L
#
# Secunderabad Junction
#
# ['', 'Laxminarayana Colony', '']
#
# Laxminarayana Colony
#
# ['19YF\n', 'Borabanda Bus Stop', '']
# 19YF
#
# Borabanda Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['19F\n', 'Borabanda Bus Stop', '']
# 19F
#
# Borabanda Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['19K\n', 'Mehdipatnam Bus Stop', '']
# 19K
#
# Mehdipatnam Bus Stop
#
# ['', 'KPHB Colony Bus Stop', '']
#
# KPHB Colony Bus Stop
#
# ['20D\n', 'JBS Bus Stop', '']
# 20D
#
# JBS Bus Stop
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['20P\n', 'Secunderabad Junction', '']
# 20P
#
# Secunderabad Junction
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['20/251\n', 'Secunderabad Junction', '']
# 20/251
#
# Secunderabad Junction
#
# ['', 'Rajiv Gandhi International Airport(Shamshabad)', '']
#
# Rajiv Gandhi International Airport(Shamshabad)
#
# ['21B\n', 'Secunderabad Junction', '']
# 21B
#
# Secunderabad Junction
#
# ['', 'Bhudevi Nagar', '']
#
# Bhudevi Nagar
#
# ['21/107J\n', 'Venkatapuram Last Bus Stop', '']
# 21/107J
#
# Venkatapuram Last Bus Stop
#
# ['', 'Saroor Nagar Bus Terminal', '']
#
# Saroor Nagar Bus Terminal
#
# ['22/1P\n', 'MGBS Bus Stop', '']
# 22/1P
#
# MGBS Bus Stop
#
# ['', 'Risala Bazar', '']
#
# Risala Bazar
#
# ['22L\n', 'Risala Bazar', '']
# 22L
#
# Risala Bazar
#
# ['', 'Lab Quarters Main Bus Stop', '']
#
# Lab Quarters Main Bus Stop
#
# ['22M\n', 'Secunderabad Junction', '']
# 22M
#
# Secunderabad Junction
#
# ['', 'Surya Nagar(Alwal)', '']
#
# Surya Nagar(Alwal)
#
# ['22T\n', 'Secunderabad Junction', '']
# 22T
#
# Secunderabad Junction
#
# ['', 'Thurakapalli', '']
#
# Thurakapalli
#
# ['22S\n', 'Risala Bazar', '']
# 22S
#
# Risala Bazar
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['22R/229\n', 'Secunderabad Junction', '']
# 22R/229
#
# Secunderabad Junction
#
# ['', 'Medchal', '']
#
# Medchal
#
# ['23B\n', 'Bhudevi Nagar', '']
# 23B
#
# Bhudevi Nagar
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['23G\n', 'Secunderabad Junction', '']
# 23G
#
# Secunderabad Junction
#
# ['', 'Clock Tower', '']
#
# Clock Tower
#
# ['24B\n', 'Secunderabad Junction', '']
# 24B
#
# Secunderabad Junction
#
# ['', 'Balaji Nagar bus stop(Balaji Nagar)', '']
#
# Balaji Nagar bus stop(Balaji Nagar)
#
# ['24E/31H\n', 'KPHB Colony Bus Stop', '']
# 24E/31H
#
# KPHB Colony Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['24E/25S\n', 'ECIL Bus Stop', '']
# 24E/25S
#
# ECIL Bus Stop
#
# ['', 'Suchitra Bus Stop', '']
#
# Suchitra Bus Stop
#
# ['24N\n', 'Secunderabad Junction', '']
# 24N
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['25J\n', 'Secunderabad Junction', '']
# 25J
#
# Secunderabad Junction
#
# ['', 'Jeedimetla Bus Stop', '']
#
# Jeedimetla Bus Stop
#
# ['25B\n', 'Secunderabad Junction', '']
# 25B
#
# Secunderabad Junction
#
# ['', 'Bank Colony(Qutubullapur)', '']
#
# Bank Colony(Qutubullapur)
#
# ['25S\n', 'Secunderabad Junction', '']
# 25S
#
# Secunderabad Junction
#
# ['', 'Suchitra Bus Stop', '']
#
# Suchitra Bus Stop
#
# ['26M\n', 'Secunderabad Junction', '']
# 26M
#
# Secunderabad Junction
#
# ['', 'Old Bowenpally Bus Stop', '']
#
# Old Bowenpally Bus Stop
#
# ['26G\n', 'Secunderabad Junction', '']
# 26G
#
# Secunderabad Junction
#
# ['', 'Green Field Colony', '']
#
# Green Field Colony
#
# ['26N/49M\n', 'Old Bowenpally Bus Stop', '']
# 26N/49M
#
# Old Bowenpally Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['26SN\n', 'Secunderabad Junction', '']
# 26SN
#
# Secunderabad Junction
#
# ['', 'Subhash Nagar(Alwal)', '']
#
# Subhash Nagar(Alwal)
#
# ['29H\n', 'Apuroopa Bus Stop', '']
# 29H
#
# Apuroopa Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['29R\n', 'Apuroopa Bus Stop', '']
# 29R
#
# Apuroopa Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['29CB\n', 'Suchitra Bus Stop', '']
# 29CB
#
# Suchitra Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['30\n', 'Jagadgiri Gutta Bus Stop', '']
# 30
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['30S\n', 'Srinivas Nagar Bus Stop', '']
# 30S
#
# Srinivas Nagar Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['30J\n', 'Jagadgiri Gutta Bus Stop', '']
# 30J
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['23\n', 'Secunderabad Junction', '']
# 23
#
# Secunderabad Junction
#
# ['', 'Subhash Nagar(Alwal)', '']
#
# Subhash Nagar(Alwal)
#
# ['23M\n', 'Secunderabad Junction', '']
# 23M
#
# Secunderabad Junction
#
# ['', 'Qutubullapur', '']
#
# Qutubullapur
#
# ['23M/283\n', 'Secunderabad Junction', '']
# 23M/283
#
# Secunderabad Junction
#
# ['', 'Suraram', '']
#
# Suraram
#
# ['24E\n', 'Secunderabad Junction', '']
# 24E
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['24N/25S\n', 'ECIL Bus Stop', '']
# 24N/25S
#
# ECIL Bus Stop
#
# ['', 'Suchitra Bus Stop', '']
#
# Suchitra Bus Stop
#
# ['24B/211RG\n', 'Secunderabad Junction', '']
# 24B/211RG
#
# Secunderabad Junction
#
# ['', 'Rajiv Gruhakalpa Colony', '']
#
# Rajiv Gruhakalpa Colony
#
# ['25I\n', 'Secunderabad Junction', '']
# 25I
#
# Secunderabad Junction
#
# ['', 'Old Alwal(IG Statue) Bus Stop', '']
#
# Old Alwal(IG Statue) Bus Stop
#
# ['25A\n', 'Secunderabad Junction', '']
# 25A
#
# Secunderabad Junction
#
# ['', 'Surya Nagar(Alwal)', '']
#
# Surya Nagar(Alwal)
#
# ['25M\n', 'Secunderabad Junction', '']
# 25M
#
# Secunderabad Junction
#
# ['', 'MG Nagar', '']
#
# MG Nagar
#
# ['26\n', 'Secunderabad Junction', '']
# 26
#
# Secunderabad Junction
#
# ['', 'Old Bowenpally Bus Stop', '']
#
# Old Bowenpally Bus Stop
#
# ['26N\n', 'Secunderabad Junction', '']
# 26N
#
# Secunderabad Junction
#
# ['', 'Old Bowenpally Bus Stop', '']
#
# Old Bowenpally Bus Stop
#
# ['26N/229\n', 'Secunderabad Junction', '']
# 26N/229
#
# Secunderabad Junction
#
# ['', 'Medchal', '']
#
# Medchal
#
# ['26S\n', 'Secunderabad Junction', '']
# 26S
#
# Secunderabad Junction
#
# ['', 'Tadbund Bus Stop', '']
#
# Tadbund Bus Stop
#
# ['27\n', 'Jeedimetla Bus Stop', '']
# 27
#
# Jeedimetla Bus Stop
#
# ['', 'Lab Quarters Main Bus Stop', '']
#
# Lab Quarters Main Bus Stop
#
# ['29Q\n', 'Suchitra Bus Stop', '']
# 29Q
#
# Suchitra Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['29S\n', 'Subhash Nagar(Jeedimetla)', '']
# 29S
#
# Subhash Nagar(Jeedimetla)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['29SN\n', 'Sai Nagar(Bala Nagar)', '']
# 29SN
#
# Sai Nagar(Bala Nagar)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['30C\n', 'Secunderabad Junction', '']
# 30C
#
# Secunderabad Junction
#
# ['', 'Asbestas Colony Bus Stop', '']
#
# Asbestas Colony Bus Stop
#
# ['30A\n', 'Allwyn Colony Bus Stop', '']
# 30A
#
# Allwyn Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['30S/31\n', 'Kukatpally Bus Stop', '']
# 30S/31
#
# Kukatpally Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['31\n', 'Secunderabad Junction', '']
# 31
#
# Secunderabad Junction
#
# ['', 'KPHB Colony Bus Stop', '']
#
# KPHB Colony Bus Stop
#
# ['31H\n', 'KPHB Colony Bus Stop', '']
# 31H
#
# KPHB Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['31V\n', 'Secunderabad Junction', '']
# 31V
#
# Secunderabad Junction
#
# ['', 'Vasanth Nagar Bus Stop', '']
#
# Vasanth Nagar Bus Stop
#
# ['32A\n', 'Secunderabad Junction', '']
# 32A
#
# Secunderabad Junction
#
# ['', 'Apuroopa Bus Stop', '']
#
# Apuroopa Bus Stop
#
# ['33N\n', 'Balaji Nagar bus stop(Balaji Nagar)', '']
# 33N
#
# Balaji Nagar bus stop(Balaji Nagar)
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['35A\n', 'A.S.Rao Nagar Bus Stop', '']
# 35A
#
# A.S.Rao Nagar Bus Stop
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['36\n', 'Yousufguda basti Bus Stop', '']
# 36
#
# Yousufguda basti Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['37AL\n', 'ECIL Bus Stop', '']
# 37AL
#
# ECIL Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['37D\n', 'Secunderabad Junction', '']
# 37D
#
# Secunderabad Junction
#
# ['', 'Ambedkar Nagar(Kapra)', '']
#
# Ambedkar Nagar(Kapra)
#
# ['37E\n', 'Secunderabad Junction', '']
# 37E
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['37S\n', 'Sanikpuri Bus Stop', '']
# 37S
#
# Sanikpuri Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['37RK\n', 'Ranigunj Bus Stop', '']
# 37RK
#
# Ranigunj Bus Stop
#
# ['', 'Kushaiguda', '']
#
# Kushaiguda
#
# ['37L/49M\n', 'Rajiv Gruhakalpa Colony', '']
# 37L/49M
#
# Rajiv Gruhakalpa Colony
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['37S/10F\n', 'ECIL Bus Stop', '']
# 37S/10F
#
# ECIL Bus Stop
#
# ['', 'Borabanda Bus Stop', '']
#
# Borabanda Bus Stop
#
# ['37/10K\n', 'ECIL Bus Stop', '']
# 37/10K
#
# ECIL Bus Stop
#
# ['', 'Kukatpally Bus Stop', '']
#
# Kukatpally Bus Stop
#
# ['38E\n', 'Secunderabad Junction', '']
# 38E
#
# Secunderabad Junction
#
# ['', 'Tukaram Gate', '']
#
# Tukaram Gate
#
# ['38K\n', 'Koti Bus Stop', '']
# 38K
#
# Koti Bus Stop
#
# ['', 'Hanumanpet', '']
#
# Hanumanpet
#
# ['38X\n', 'Secunderabad Junction', '']
# 38X
#
# Secunderabad Junction
#
# ['', 'Sangeeth', '']
#
# Sangeeth
#
# ['38S/47V\n', 'Safilguda Bus Stop', '']
# 38S/47V
#
# Safilguda Bus Stop
#
# ['', 'VBIT(Ascendas IT Park)', '']
#
# VBIT(Ascendas IT Park)
#
# ['40\n', 'Secunderabad Junction', '']
# 40
#
# Secunderabad Junction
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['31A\n', 'Secunderabad Junction', '']
# 31A
#
# Secunderabad Junction
#
# ['', 'Kukatpally Bus Stop', '']
#
# Kukatpally Bus Stop
#
# ['31P\n', 'Secunderabad Junction', '']
# 31P
#
# Secunderabad Junction
#
# ['', 'Sri Sai Nagar Lake', '']
#
# Sri Sai Nagar Lake
#
# ['31L\n', 'Secunderabad Junction', '']
# 31L
#
# Secunderabad Junction
#
# ['', 'KPHB Colony Bus Stop', '']
#
# KPHB Colony Bus Stop
#
# ['33S\n', 'Secunderabad Junction', '']
# 33S
#
# Secunderabad Junction
#
# ['', 'Allwyn Colony Bus Stop', '']
#
# Allwyn Colony Bus Stop
#
# ['34\n', 'Secunderabad Junction', '']
# 34
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['35\n', 'Apuroopa Bus Stop', '']
# 35
#
# Apuroopa Bus Stop
#
# ['', 'VBIT(Ascendas IT Park)', '']
#
# VBIT(Ascendas IT Park)
#
# ['37\n', 'ECIL Bus Stop', '']
# 37
#
# ECIL Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['37B\n', 'Secunderabad Junction', '']
# 37B
#
# Secunderabad Junction
#
# ['', 'Ambedkar Nagar(Kapra)', '']
#
# Ambedkar Nagar(Kapra)
#
# ['37DL\n', 'Secunderabad Junction', '']
# 37DL
#
# Secunderabad Junction
#
# ['', 'Ambedkar Nagar(Kapra)', '']
#
# Ambedkar Nagar(Kapra)
#
# ['37H\n', 'Secunderabad Junction', '']
# 37H
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['37N\n', 'ECIL Bus Stop', '']
# 37N
#
# ECIL Bus Stop
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['37N/49M\n', 'ECIL Bus Stop', '']
# 37N/49M
#
# ECIL Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['37/250\n', 'Secunderabad Junction', '']
# 37/250
#
# Secunderabad Junction
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['37/47\n', 'ECIL Bus Stop', '']
# 37/47
#
# ECIL Bus Stop
#
# ['', 'Film Nagar', '']
#
# Film Nagar
#
# ['38A\n', 'RTC Colony(Moula ali)', '']
# 38A
#
# RTC Colony(Moula ali)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['38H\n', 'Secunderabad Junction', '']
# 38H
#
# Secunderabad Junction
#
# ['', 'Hanumanpet', '']
#
# Hanumanpet
#
# ['38LC\n', 'Secunderabad Junction', '']
# 38LC
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['38EX\n', 'Secunderabad Junction', '']
# 38EX
#
# Secunderabad Junction
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['39K\n', 'Koti Bus Stop', '']
# 39K
#
# Koti Bus Stop
#
# ['', 'Balanagar Bus Stop', '']
#
# Balanagar Bus Stop
#
# ['40D\n', 'Secunderabad Junction', '']
# 40D
#
# Secunderabad Junction
#
# ['', 'Dilsukhnagar Bus station', '']
#
# Dilsukhnagar Bus station
#
# ['40N\n', 'Secunderabad Junction', '']
# 40N
#
# Secunderabad Junction
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['40T\n', 'Koti Bus Stop', '']
# 40T
#
# Koti Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['41\n', 'Jagadgiri Gutta Bus Stop', '']
# 41
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['41K\n', 'Jagadgiri Gutta Bus Stop', '']
# 41K
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['41S/185\n', 'Jagadgiri Gutta Bus Stop', '']
# 41S/185
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'Jagadgiri Gutta Bus Stop', '']
#
# Jagadgiri Gutta Bus Stop
#
# ['44\n', 'Gangaputra Colony Bus Stop', '']
# 44
#
# Gangaputra Colony Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['44X\n', 'Secunderabad Junction', '']
# 44X
#
# Secunderabad Junction
#
# ['', 'Gangaputra Colony Bus Stop', '']
#
# Gangaputra Colony Bus Stop
#
# ['45A\n', 'Koti Bus Stop', '']
# 45A
#
# Koti Bus Stop
#
# ['', 'A G Colony', '']
#
# A G Colony
#
# ['45J\n', 'Jeedimetla Bus Stop', '']
# 45J
#
# Jeedimetla Bus Stop
#
# ['', 'RTC Cross Rd', '']
#
# RTC Cross Rd
#
# ['45Y\n', 'Koti Bus Stop', '']
# 45Y
#
# Koti Bus Stop
#
# ['', 'Yousufguda basti Bus Stop', '']
#
# Yousufguda basti Bus Stop
#
# ['45F\n', 'Borabanda Bus Stop', '']
# 45F
#
# Borabanda Bus Stop
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['45MF\n', 'Ram Nagar', '']
# 45MF
#
# Ram Nagar
#
# ['', 'Borabanda Bus Stop', '']
#
# Borabanda Bus Stop
#
# ['45RF\n', 'Ram Nagar', '']
# 45RF
#
# Ram Nagar
#
# ['', 'Borabanda Bus Stop', '']
#
# Borabanda Bus Stop
#
# ['47F\n', 'Secunderabad Junction', '']
# 47F
#
# Secunderabad Junction
#
# ['', 'Film Nagar', '']
#
# Film Nagar
#
# ['47H\n', 'Secunderabad Junction', '']
# 47H
#
# Secunderabad Junction
#
# ['', 'Hafeezpet Bus Stop', '']
#
# Hafeezpet Bus Stop
#
# ['47L\n', 'Secunderabad Junction', '']
# 47L
#
# Secunderabad Junction
#
# ['', 'Film Nagar', '']
#
# Film Nagar
#
# ['47S\n', 'Secunderabad Junction', '']
# 47S
#
# Secunderabad Junction
#
# ['', 'Shilparamam parking(hitech city)', '']
#
# Shilparamam parking(hitech city)
#
# ['47LV\n', 'VBIT(Ascendas IT Park)', '']
# 47LV
#
# VBIT(Ascendas IT Park)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['47V\n', 'Secunderabad Junction', '']
# 47V
#
# Secunderabad Junction
#
# ['', 'VBIT(Ascendas IT Park)', '']
#
# VBIT(Ascendas IT Park)
#
# ['48\n', 'Kachiguda Bus Stop', '']
# 48
#
# Kachiguda Bus Stop
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['40I\n', 'Secunderabad Junction', '']
# 40I
#
# Secunderabad Junction
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['40V\n', 'Koti Bus Stop', '']
# 40V
#
# Koti Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['41C\n', 'Koti Bus Stop', '']
# 41C
#
# Koti Bus Stop
#
# ['', 'Asbestas Colony Bus Stop', '']
#
# Asbestas Colony Bus Stop
#
# ['41N\n', 'Jagadgiri Gutta Bus Stop', '']
# 41N
#
# Jagadgiri Gutta Bus Stop
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['43\n', 'Secunderabad Junction', '']
# 43
#
# Secunderabad Junction
#
# ['', 'Vampuguda', '']
#
# Vampuguda
#
# ['44L\n', 'Gangaputra Colony Bus Stop', '']
# 44L
#
# Gangaputra Colony Bus Stop
#
# ['', 'Lalaguda Bus Stop', '']
#
# Lalaguda Bus Stop
#
# ['45\n', 'VST Bus Stop', '']
# 45
#
# VST Bus Stop
#
# ['', 'ESI Bus Stop', '']
#
# ESI Bus Stop
#
# ['45G\n', 'Ram Nagar', '']
# 45G
#
# Ram Nagar
#
# ['', 'Jubilee Hills', '']
#
# Jubilee Hills
#
# ['45K\n', 'Koti Bus Stop', '']
# 45K
#
# Koti Bus Stop
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['45GY\n', 'Jagapathi Hills', '']
# 45GY
#
# Jagapathi Hills
#
# ['', 'Ram Nagar', '']
#
# Ram Nagar
#
# ['45S\n', 'Koti Bus Stop', '']
# 45S
#
# Koti Bus Stop
#
# ['', 'Sanath Nagar Bus Stop', '']
#
# Sanath Nagar Bus Stop
#
# ['45MH\n', 'Ram Nagar', '']
# 45MH
#
# Ram Nagar
#
# ['', 'Kondapur Bus Stop', '']
#
# Kondapur Bus Stop
#
# ['47C\n', 'Film Nagar', '']
# 47C
#
# Film Nagar
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['47G\n', 'Secunderabad Junction', '']
# 47G
#
# Secunderabad Junction
#
# ['', 'GPFA QTRS', '']
#
# GPFA QTRS
#
# ['47K\n', 'Kondapur Bus Stop', '']
# 47K
#
# Kondapur Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['47Y\n', 'Film Nagar', '']
# 47Y
#
# Film Nagar
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['47YG\n', 'Secunderabad Junction', '']
# 47YG
#
# Secunderabad Junction
#
# ['', 'Film Nagar', '']
#
# Film Nagar
#
# ['47N\n', 'Secunderabad Junction', '']
# 47N
#
# Secunderabad Junction
#
# ['', 'Nandi Nagar Bus Stop', '']
#
# Nandi Nagar Bus Stop
#
# ['47ZC\n', 'Secunderabad Junction', '']
# 47ZC
#
# Secunderabad Junction
#
# ['', 'LV Prasad Bus Stop', '']
#
# LV Prasad Bus Stop
#
# ['49\n', 'Secunderabad Junction', '']
# 49
#
# Secunderabad Junction
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['49A\n', 'Jaheer Nagar', '']
# 49A
#
# Jaheer Nagar
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['49J\n', 'Secunderabad Junction', '']
# 49J
#
# Secunderabad Junction
#
# ['', 'Jubilee Checkpost Bus Stop', '']
#
# Jubilee Checkpost Bus Stop
#
# ['49L\n', 'Secunderabad Junction', '']
# 49L
#
# Secunderabad Junction
#
# ['', 'MLA Colony Bus Stop', '']
#
# MLA Colony Bus Stop
#
# ['49N\n', 'Secunderabad Junction', '']
# 49N
#
# Secunderabad Junction
#
# ['', 'Nandi Nagar Bus Stop', '']
#
# Nandi Nagar Bus Stop
#
# ['49V\n', 'Secunderabad Junction', '']
# 49V
#
# Secunderabad Junction
#
# ['', 'Erramanzil Bus Stop', '']
#
# Erramanzil Bus Stop
#
# ['49M/250\n', 'Mehdipatnam Bus Stop', '']
# 49M/250
#
# Mehdipatnam Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['49Z\n', 'Secunderabad Junction', '']
# 49Z
#
# Secunderabad Junction
#
# ['', 'Zoo Park', '']
#
# Zoo Park
#
# ['51\n', 'Secunderabad Junction', '']
# 51
#
# Secunderabad Junction
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['57ST\n', 'Secunderabad Junction', '']
# 57ST
#
# Secunderabad Junction
#
# ['', 'Tallagada', '']
#
# Tallagada
#
# ['63K\n', 'Ahmed Nagar', '']
# 63K
#
# Ahmed Nagar
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['63S\n', 'Syed Nagar', '']
# 63S
#
# Syed Nagar
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65\n', 'Tolichowki Bus Stop', '']
# 65
#
# Tolichowki Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65C\n', 'Moti Darwaza', '']
# 65C
#
# Moti Darwaza
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65G\n', 'Charminar Bus Stop', '']
# 65G
#
# Charminar Bus Stop
#
# ['', 'Golkonda Bus Stop', '']
#
# Golkonda Bus Stop
#
# ['65M\n', 'Charminar Bus Stop', '']
# 65M
#
# Charminar Bus Stop
#
# ['', 'Langar House Bus Stop', '']
#
# Langar House Bus Stop
#
# ['65S\n', 'Shah ali banda New Bus Stop', '']
# 65S
#
# Shah ali banda New Bus Stop
#
# ['', 'Shaikpet Darga Bus Stop', '']
#
# Shaikpet Darga Bus Stop
#
# ['65V\n', 'Charminar Bus Stop', '']
# 65V
#
# Charminar Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['66G\n', 'Shah ali banda New Bus Stop', '']
# 66G
#
# Shah ali banda New Bus Stop
#
# ['', 'Golkonda Bus Stop', '']
#
# Golkonda Bus Stop
#
# ['67\n', 'Charminar Bus Stop', '']
# 67
#
# Charminar Bus Stop
#
# ['', 'Uppuguda', '']
#
# Uppuguda
#
# ['67K\n', 'Charminar Bus Stop', '']
# 67K
#
# Charminar Bus Stop
#
# ['', 'Kesav Giri', '']
#
# Kesav Giri
#
# ['49E\n', 'Gachibowli Bus Station', '']
# 49E
#
# Gachibowli Bus Station
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['49K\n', 'Secunderabad Junction', '']
# 49K
#
# Secunderabad Junction
#
# ['', 'Kachiguda Bus Stop', '']
#
# Kachiguda Bus Stop
#
# ['49M\n', 'Secunderabad Junction', '']
# 49M
#
# Secunderabad Junction
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['49P\n', 'Secunderabad Junction', '']
# 49P
#
# Secunderabad Junction
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['49/86\n', 'Secunderabad Junction', '']
# 49/86
#
# Secunderabad Junction
#
# ['', 'Chilakalguda(Gandhi Statue)', '']
#
# Chilakalguda(Gandhi Statue)
#
# ['49M/251\n', 'Secunderabad Junction', '']
# 49M/251
#
# Secunderabad Junction
#
# ['', 'Rajiv Gandhi International Airport(Shamshabad)', '']
#
# Rajiv Gandhi International Airport(Shamshabad)
#
# ['50B\n', 'Uppal X Road Bus Stop', '']
# 50B
#
# Uppal X Road Bus Stop
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['57S\n', 'Secunderabad Junction', '']
# 57S
#
# Secunderabad Junction
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['63B\n', 'Ahmed Nagar', '']
# 63B
#
# Ahmed Nagar
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['63M\n', 'Ahmed Nagar', '']
# 63M
#
# Ahmed Nagar
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['63SB\n', 'Syed Nagar', '']
# 63SB
#
# Syed Nagar
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65A\n', 'Ambedkar Nagar(Chinthal Basthi)', '']
# 65A
#
# Ambedkar Nagar(Chinthal Basthi)
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65/85\n', 'Mehdipatnam Bus Stop', '']
# 65/85
#
# Mehdipatnam Bus Stop
#
# ['', 'Barkas', '']
#
# Barkas
#
# ['65GP\n', 'Golkonda Bus Stop', '']
# 65GP
#
# Golkonda Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65P\n', 'Puppalaguda', '']
# 65P
#
# Puppalaguda
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['65T\n', 'Charminar Bus Stop', '']
# 65T
#
# Charminar Bus Stop
#
# ['', 'Tallagada', '']
#
# Tallagada
#
# ['65Z\n', 'Zoo Park', '']
# 65Z
#
# Zoo Park
#
# ['', 'Langar House Bus Stop', '']
#
# Langar House Bus Stop
#
# ['66P\n', 'Golkonda Bus Stop', '']
# 66P
#
# Golkonda Bus Stop
#
# ['', 'Pahadi Shareef', '']
#
# Pahadi Shareef
#
# ['67B\n', 'Koti Bus Stop', '']
# 67B
#
# Koti Bus Stop
#
# ['', 'Uppuguda', '']
#
# Uppuguda
#
# ['67L\n', 'Koti Bus Stop', '']
# 67L
#
# Koti Bus Stop
#
# ['', 'Lalitha Bagh', '']
#
# Lalitha Bagh
#
# ['70\n', 'Charminar Bus Stop', '']
# 70
#
# Charminar Bus Stop
#
# ['', 'Teegala Kunta', '']
#
# Teegala Kunta
#
# ['70/65\n', 'Mehdipatnam Bus Stop', '']
# 70/65
#
# Mehdipatnam Bus Stop
#
# ['', 'Teegala Kunta', '']
#
# Teegala Kunta
#
# ['70M\n', 'Charminar Bus Stop', '']
# 70M
#
# Charminar Bus Stop
#
# ['', 'Mustafa Nagar', '']
#
# Mustafa Nagar
#
# ['71A\n', 'Uppal Bus Stop', '']
# 71A
#
# Uppal Bus Stop
#
# ['', 'Charminar Bus Stop', '']
#
# Charminar Bus Stop
#
# ['71D\n', 'Uppal Bus Stop', '']
# 71D
#
# Uppal Bus Stop
#
# ['', 'Dilsukhnagar Bus station', '']
#
# Dilsukhnagar Bus station
#
# ['72\n', 'Charminar Bus Stop', '']
# 72
#
# Charminar Bus Stop
#
# ['', 'Dilsukhnagar Bus station', '']
#
# Dilsukhnagar Bus station
#
# ['72B\n', 'Dilsukhnagar Bus station', '']
# 72B
#
# Dilsukhnagar Bus station
#
# ['', 'Balapur', '']
#
# Balapur
#
# ['72JY\n', 'LB Nagar Bus Stop', '']
# 72JY
#
# LB Nagar Bus Stop
#
# ['', 'Kesari Hanuman Temple', '']
#
# Kesari Hanuman Temple
#
# ['72M\n', 'Charminar Bus Stop', '']
# 72M
#
# Charminar Bus Stop
#
# ['', 'New Maruthi Nagar', '']
#
# New Maruthi Nagar
#
# ['72R/8A\n', 'Secunderabad Junction', '']
# 72R/8A
#
# Secunderabad Junction
#
# ['', 'Rajanna Bai', '']
#
# Rajanna Bai
#
# ['72LR\n', 'Charminar Bus Stop', '']
# 72LR
#
# Charminar Bus Stop
#
# ['', 'FCI Colony', '']
#
# FCI Colony
#
# ['73\n', 'Chandulal Baradari', '']
# 73
#
# Chandulal Baradari
#
# ['', 'Koti Bus Stop', '']
#
# Koti Bus Stop
#
# ['75A\n', 'Charminar Bus Stop', '']
# 75A
#
# Charminar Bus Stop
#
# ['', 'Arundhathi Colony', '']
#
# Arundhathi Colony
#
# ['75U\n', 'Charminar Bus Stop', '']
# 75U
#
# Charminar Bus Stop
#
# ['', 'Uppuguda', '']
#
# Uppuguda
#
# ['78S\n', 'Charminar Bus Stop', '']
# 78S
#
# Charminar Bus Stop
#
# ['', 'Sagar Housing Complex', '']
#
# Sagar Housing Complex
#
# ['78H\n', 'High Court(Post Office)', '']
# 78H
#
# High Court(Post Office)
#
# ['', 'LB Nagar Bus Stop', '']
#
# LB Nagar Bus Stop
#
# ['80D\n', 'Dilsukhnagar Bus station', '']
# 80D
#
# Dilsukhnagar Bus station
#
# ...
#
# ['288M\n', 'Mehdipatnam Bus Stop', '']
# 288M
#
# Mehdipatnam Bus Stop
#
# ['', 'Kanakamamidi', '']
#
# Kanakamamidi
#
# ['288P\n', 'Mehdipatnam Bus Stop', '']
# 288P
#
# Mehdipatnam Bus Stop
#
# ['', 'Peddamangalaram', '']
#
# Peddamangalaram
#
# ['288S\n', 'Mehdipatnam Bus Stop', '']
# 288S
#
# Mehdipatnam Bus Stop
#
# ['', 'Sai Ram Nagar(Langar House)', '']
#
# Sai Ram Nagar(Langar House)
#
# ['288Y\n', 'Mehdipatnam Bus Stop', '']
# 288Y
#
# Mehdipatnam Bus Stop
#
# ['', 'Yelkaguda', '']
#
# Yelkaguda
#
# ['289M\n', 'Suraram', '']
# 289M
#
# Suraram
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['290J\n', 'Hayath Nagar Bus Stop', '']
# 290J
#
# Hayath Nagar Bus Stop
#
# ['', 'JBS Bus Stop', '']
#
# JBS Bus Stop
#
# ['290KP\n', 'Kavvadipally', '']
# 290KP
#
# Kavvadipally
#
# ['', 'JBS Bus Stop', '']
#
# JBS Bus Stop
#
# ['290S\n', 'Secunderabad Junction', '']
# 290S
#
# Secunderabad Junction
#
# ['', 'Sanghi Nagar', '']
#
# Sanghi Nagar
#
# ['290\n', 'Hayath Nagar Bus Stop', '']
# 290
#
# Hayath Nagar Bus Stop
#
# ['', 'JBS Bus Stop', '']
#
# JBS Bus Stop
#
# ['280N\n', 'Secunderabad Junction', '']
# 280N
#
# Secunderabad Junction
#
# ['', 'NFC Nagar', '']
#
# NFC Nagar
#
# ['280\n', 'Secunderabad Junction', '']
# 280
#
# Secunderabad Junction
#
# ['', 'Ghatkesar Bus Stop', '']
#
# Ghatkesar Bus Stop
#
# ['281\n', 'ECIL Bus Stop', '']
# 281
#
# ECIL Bus Stop
#
# ['', 'Ghatkesar Bus Stop', '']
#
# Ghatkesar Bus Stop
#
# ['283D\n', 'Suraram', '']
# 283D
#
# Suraram
#
# ['', 'CBS Bus Stop', '']
#
# CBS Bus Stop
#
# ['283N\n', 'Saibaba Nagar(Jeedimetla)', '']
# 283N
#
# Saibaba Nagar(Jeedimetla)
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['283\n', 'Koti Bus Stop', '']
# 283
#
# Koti Bus Stop
#
# ['', 'Bacharam', '']
#
# Bacharam
#
# ['284G\n', 'Uppal Bus Stop', '']
# 284G
#
# Uppal Bus Stop
#
# ['', 'Ghatkesar Bus Stop', '']
#
# Ghatkesar Bus Stop
#
# ['284S\n', 'Secunderabad Junction', '']
# 284S
#
# Secunderabad Junction
#
# ['', 'Pratapsingaram', '']
#
# Pratapsingaram
#
# ['288/19F\n', 'Mehdipatnam Bus Stop', '']
# 288/19F
#
# Mehdipatnam Bus Stop
#
# ['', 'Borabanda Bus Stop', '']
#
# Borabanda Bus Stop
#
# ['288B\n', 'Mehdipatnam Bus Stop', '']
# 288B
#
# Mehdipatnam Bus Stop
#
# ['', 'Bakaram', '']
#
# Bakaram
#
# ['288D\n', 'Mehdipatnam Bus Stop', '']
# 288D
#
# Mehdipatnam Bus Stop
#
# ['', 'Chilkur Balaji Temple', '']
#
# Chilkur Balaji Temple
#
# ['288N\n', 'Mehdipatnam Bus Stop', '']
# 288N
#
# Mehdipatnam Bus Stop
#
# ['', 'Bakaram', '']
#
# Bakaram
#
# ['288R\n', 'Mehdipatnam Bus Stop', '']
# 288R
#
# Mehdipatnam Bus Stop
#
# ['', 'Chinnamangalaram', '']
#
# Chinnamangalaram
#
# ['288X\n', 'Mehdipatnam Bus Stop', '']
# 288X
#
# Mehdipatnam Bus Stop
#
# ['', 'Mothukulapalli', '']
#
# Mothukulapalli
#
# ['288\n', 'Mehdipatnam Bus Stop', '']
# 288
#
# Mehdipatnam Bus Stop
#
# ['', 'Moinabad', '']
#
# Moinabad
#
# ['290AF\n', 'JBS Bus Stop', '']
# 290AF
#
# JBS Bus Stop
#
# ['', 'Anajpur', '']
#
# Anajpur
#
# ['290K\n', 'Secunderabad Junction', '']
# 290K
#
# Secunderabad Junction
#
# ['', 'Koheda', '']
#
# Koheda
#
# ['290Q\n', 'Secunderabad Junction', '']
# 290Q
#
# Secunderabad Junction
#
# ['', 'Hayath Nagar Bus Stop', '']
#
# Hayath Nagar Bus Stop
#
# ['290U\n', 'Hayath Nagar Bus Stop', '']
# 290U
#
# Hayath Nagar Bus Stop
#
# ['', 'Uppal X Road Bus Stop', '']
#
# Uppal X Road Bus Stop
#
# ['290/250\n', 'Hayath Nagar Bus Stop', '']
# 290/250
#
# Hayath Nagar Bus Stop
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['291\n', 'JBS Bus Stop', '']
# 291
#
# JBS Bus Stop
#
# ['', 'Pillaipalli', '']
#
# Pillaipalli
#
# ['293\n', 'Saheb Nagar(Vanasthalipuram)', '']
# 293
#
# Saheb Nagar(Vanasthalipuram)
#
# ['', 'Nampally', '']
#
# Nampally
#
# ['299D\n', 'Hayath Nagar Bus Stop', '']
# 299D
#
# Hayath Nagar Bus Stop
#
# ['', 'Dilsukhnagar Bus station', '']
#
# Dilsukhnagar Bus station
#
# ['299M\n', 'Hayath Nagar Bus Stop', '']
# 299M
#
# Hayath Nagar Bus Stop
#
# ['', 'Mehdipatnam Bus Stop', '']
#
# Mehdipatnam Bus Stop
#
# ['299S\n', 'Womens college Bus Stop', '']
# 299S
#
# Womens college Bus Stop
#
# ['', 'Saheb Nagar(Vanasthalipuram)', '']
#
# Saheb Nagar(Vanasthalipuram)
#
# ['401\n', 'Ibrahimpatnam Bus Station', '']
# 401
#
# Ibrahimpatnam Bus Station
#
# ['', 'Mudwin', '']
#
# Mudwin
#
# ['403\n', 'Ibrahimpatnam Bus Station', '']
# 403
#
# Ibrahimpatnam Bus Station
#
# ['', 'Gaddamallaiguda', '']
#
# Gaddamallaiguda
#
# ['405\n', 'Ibrahimpatnam Bus Station', '']
# 405
#
# Ibrahimpatnam Bus Station
#
# ['', 'Tadipatri', '']
#
# Tadipatri
#
# ['407\n', 'Ibrahimpatnam Bus Station', '']
# 407
#
# Ibrahimpatnam Bus Station
#
# ['', 'Kothapalli', '']
#
# Kothapalli
#
# ['409\n', 'Ibrahimpatnam Bus Station', '']
# 409
#
# Ibrahimpatnam Bus Station
#
# ['', 'Elgapally Tanda', '']
#
# Elgapally Tanda
#
# ['411\n', 'Ibrahimpatnam Bus Station', '']
# 411
#
# Ibrahimpatnam Bus Station
#
# ['', 'Nerrapally', '']
#
# Nerrapally
#
# ['413\n', 'Ibrahimpatnam Bus Station', '']
# 413
#
# Ibrahimpatnam Bus Station
#
# ['', 'Nanaknagar', '']
#
# Nanaknagar
#
# ['422\n', 'Ibrahimpatnam Bus Station', '']
# 422
#
# Ibrahimpatnam Bus Station
#
# ['', 'Dandumailaram', '']
#
# Dandumailaram
#
# ['428\n', 'Ibrahimpatnam Bus Station', '']
# 428
#
# Ibrahimpatnam Bus Station
#
# ['', 'Arutla', '']
#
# Arutla
#
# ['431\n', 'Ibrahimpatnam Bus Station', '']
# 431
#
# Ibrahimpatnam Bus Station
#
# ['', 'Arutla', '']
#
# Arutla
#
# ['434\n', 'Ibrahimpatnam Bus Station', '']
# 434
#
# Ibrahimpatnam Bus Station
#
# ['', 'Kudaspally', '']
#
# Kudaspally
#
# ['439\n', 'Ibrahimpatnam Bus Station', '']
# 439
#
# Ibrahimpatnam Bus Station
#
# ['', 'Tipaiguda', '']
#
# Tipaiguda
#
# ['443\n', 'Mehdipatnam Bus Stop', '']
# 443
#
# Mehdipatnam Bus Stop
#
# ['', 'Nakkalapally', '']
#
# Nakkalapally
#
# ['445\n', 'Mehdipatnam Bus Stop', '']
# 445
#
# Mehdipatnam Bus Stop
#
# ['', 'KethiReedy Pally', '']
#
# KethiReedy Pally
#
# ['448\n', 'Afzalgunj Bus Stop', '']
# 448
#
# Afzalgunj Bus Stop
#
# ['', 'Maheshwaram', '']
#
# Maheshwaram
#
# ['293S\n', 'Womens college Bus Stop', '']
# 293S
#
# Womens college Bus Stop
#
# ['', 'Sanghi Nagar', '']
#
# Sanghi Nagar
#
# ['299A\n', 'Hayath Nagar Bus Stop', '']
# 299A
#
# Hayath Nagar Bus Stop
#
# ['', 'Afzalgunj Bus Stop', '']
#
# Afzalgunj Bus Stop
#
# ['299H\n', 'Womens college Bus Stop', '']
# 299H
#
# Womens college Bus Stop
#
# ['', 'High Court Colony Bus Stop', '']
#
# High Court Colony Bus Stop
#
# ['299P\n', 'Womens college Bus Stop', '']
# 299P
#
# Womens college Bus Stop
#
# ['', 'Sanghi Nagar', '']
#
# Sanghi Nagar
#
# ['299\n', 'Womens college Bus Stop', '']
# 299
#
# Womens college Bus Stop
#
# ['', 'Hayath Nagar Bus Stop', '']
#
# Hayath Nagar Bus Stop
#
# ['402\n', 'Ibrahimpatnam Bus Station', '']
# 402
#
# Ibrahimpatnam Bus Station
#
# ['', 'Ghattuppal', '']
#
# Ghattuppal
#
# ['404\n', 'Ibrahimpatnam Bus Station', '']
# 404
#
# Ibrahimpatnam Bus Station
#
# ['', 'Mall', '']
#
# Mall
#
# ['406\n', 'Ibrahimpatnam Bus Station', '']
# 406
#
# Ibrahimpatnam Bus Station
#
# ['', 'Datpally', '']
#
# Datpally
#
# ['408\n', 'Ibrahimpatnam Bus Station', '']
# 408
#
# Ibrahimpatnam Bus Station
#
# ['', 'Ajilapur', '']
#
# Ajilapur
#
# ['410\n', 'Ibrahimpatnam Bus Station', '']
# 410
#
# Ibrahimpatnam Bus Station
#
# ['', 'Kandukur', '']
#
# Kandukur
#
# ['412\n', 'Ibrahimpatnam Bus Station', '']
# 412
#
# Ibrahimpatnam Bus Station
#
# ['', 'Tadipatri', '']
#
# Tadipatri
#
# ['421\n', 'Ibrahimpatnam Bus Station', '']
# 421
#
# Ibrahimpatnam Bus Station
#
# ['', 'Dandumailaram', '']
#
# Dandumailaram
#
# ['427\n', 'Ibrahimpatnam Bus Station', '']
# 427
#
# Ibrahimpatnam Bus Station
#
# ['', 'Japal', '']
#
# Japal
#
# ['430\n', 'Ibrahimpatnam Bus Station', '']
# 430
#
# Ibrahimpatnam Bus Station
#
# ['', 'P C tanda', '']
#
# P C tanda
#
# ['433\n', 'Ibrahimpatnam Bus Station', '']
# 433
#
# Ibrahimpatnam Bus Station
#
# ['', 'Azzinatanda', '']
#
# Azzinatanda
#
# ['436\n', 'Ibrahimpatnam Bus Station', '']
# 436
#
# Ibrahimpatnam Bus Station
#
# ['', 'Azzinatanda', '']
#
# Azzinatanda
#
# ['440\n', 'Ibrahimpatnam Bus Station', '']
# 440
#
# Ibrahimpatnam Bus Station
#
# ['', 'Kappad', '']
#
# Kappad
#
# ['444\n', 'Mehdipatnam Bus Stop', '']
# 444
#
# Mehdipatnam Bus Stop
#
# ['', 'Yenkapally', '']
#
# Yenkapally
#
# ['446\n', 'Mehdipatnam Bus Stop', '']
# 446
#
# Mehdipatnam Bus Stop
#
# ['', 'Venkatapur Bus Stop', '']
#
# Venkatapur Bus Stop
#
# ['449\n', 'Afzalgunj Bus Stop', '']
# 449
#
# Afzalgunj Bus Stop
#
# ['', 'Mallapur(shamshabad)', '']
#
# Mallapur(shamshabad)
#
# ['450\n', 'Afzalgunj Bus Stop', '']
# 450
#
# Afzalgunj Bus Stop
#
# ['', 'Solipet', '']
#
# Solipet
#
# ['453\n', 'Afzalgunj Bus Stop', '']
# 453
#
# Afzalgunj Bus Stop
#
# ['', 'Guduru village', '']
#
# Guduru village
#
# ['458\n', 'Afzalgunj Bus Stop', '']
# 458
#
# Afzalgunj Bus Stop
#
# ['', 'Manikyamma Colony', '']
#
# Manikyamma Colony
#
# ['460\n', 'Womens college Bus Stop', '']
# 460
#
# Womens college Bus Stop
#
# ['', 'Bachupally', '']
#
# Bachupally
#
# ['462\n', 'Womens college Bus Stop', '']
# 462
#
# Womens college Bus Stop
#
# ['', 'Piglipuram', '']
#
# Piglipuram
#
# ['464\n', 'Dandumailaram', '']
# 464
#
# Dandumailaram
#
# ['', 'Womens college Bus Stop', '']
#
# Womens college Bus Stop
#
# ['468\n', 'Ibrahimpatnam Bus Station', '']
# 468
#
# Ibrahimpatnam Bus Station
#
# ['', 'Kandukur', '']
#
# Kandukur
#
# ['470\n', 'Ibrahimpatnam Bus Station', '']
# 470
#
# Ibrahimpatnam Bus Station
#
# ['', 'Malagudem', '']
#
# Malagudem
#
# ['471K\n', 'Womens college Bus Stop', '']
# 471K
#
# Womens college Bus Stop
#
# ['', 'Kandukur', '']
#
# Kandukur
#
# ['472\n', 'Afzalgunj Bus Stop', '']
# 472
#
# Afzalgunj Bus Stop
#
# ['', 'Siddapur', '']
#
# Siddapur
#
# ['474\n', 'Womens college Bus Stop', '']
# 474
#
# Womens college Bus Stop
#
# ['', 'Dasrlapally', '']
#
# Dasrlapally
#
# ['477\n', 'Charminar Bus Stop', '']
# 477
#
# Charminar Bus Stop
#
# ['', 'Timmapur', '']
#
# Timmapur
#
# ['479\n', 'Womens college Bus Stop', '']
# 479
#
# Womens college Bus Stop
#
# ['', 'Rachalooru', '']
#
# Rachalooru
#
# ['482\n', 'Ibrahimpatnam Bus Station', '']
# 482
#
# Ibrahimpatnam Bus Station
#
# ['', 'Chotuppal', '']
#
# Chotuppal
#
# ['485\n', 'Vijaya Hospital', '']
# 485
#
# Vijaya Hospital
#
# ['', 'Womens college Bus Stop', '']
#
# Womens college Bus Stop
#
# ['487\n', 'Womens college Bus Stop', '']
# 487
#
# Womens college Bus Stop
#
# ['', 'Porandla', '']
#
# Porandla
#
# ['490\n', 'Secunderabad Junction', '']
# 490
#
# Secunderabad Junction
#
# ['', 'Bibinagar', '']
#
# Bibinagar
#
# ['492\n', 'Koti Bus Stop', '']
# 492
#
# Koti Bus Stop
#
# ['', 'Chinaravulapally', '']
#
# Chinaravulapally
#
# ['494\n', 'JBS Bus Stop', '']
# 494
#
# JBS Bus Stop
#
# ['', 'Jiyapally', '']
#
# Jiyapally
#
# ['495\n', 'Medchal', '']
# 495
#
# Medchal
#
# ['', 'Jinnaram', '']
#
# Jinnaram
#
# ['451\n', 'Afzalgunj Bus Stop', '']
# 451
#
# Afzalgunj Bus Stop
#
# ['', 'Akanpally', '']
#
# Akanpally
#
# ['454\n', 'Afzalgunj Bus Stop', '']
# 454
#
# Afzalgunj Bus Stop
#
# ['', 'Botiguda', '']
#
# Botiguda
#
# ['459\n', 'Ibrahimpatnam Bus Station', '']
# 459
#
# Ibrahimpatnam Bus Station
#
# ['', 'Shivannaguda', '']
#
# Shivannaguda
#
# ['461\n', 'Ibrahimpatnam Bus Station', '']
# 461
#
# Ibrahimpatnam Bus Station
#
# ['', 'Ameerpet Bus Station', '']
#
# Ameerpet Bus Station
#
# ['463\n', 'Deshmukhi', '']
# 463
#
# Deshmukhi
#
# ['', 'Dilsukhnagar Bus station', '']
#
# Dilsukhnagar Bus station
#
# ['467\n', 'Yacharam(Nagarjuna Sagar Road)', '']
# 467
#
# Yacharam(Nagarjuna Sagar Road)
#
# ['', 'Kandukur', '']
#
# Kandukur
#
# ['469\n', 'Ibrahimpatnam Bus Station', '']
# 469
#
# Ibrahimpatnam Bus Station
#
# ['', 'Meerkhanpet', '']
#
# Meerkhanpet
#
# ['471C\n', 'MGBS Bus Stop', '']
# 471C
#
# MGBS Bus Stop
#
# ['', 'Chippalapally', '']
#
# Chippalapally
#
# ['471\n', 'Charminar Bus Stop', '']
# 471
#
# Charminar Bus Stop
#
# ['', 'Mannyaguda', '']
#
# Mannyaguda
#
# ['473\n', 'Womens college Bus Stop', '']
# 473
#
# Womens college Bus Stop
#
# ['', 'Dabbadaguda', '']
#
# Dabbadaguda
#
# ['475\n', 'Afzalgunj Bus Stop', '']
# 475
#
# Afzalgunj Bus Stop
#
# ['', 'Kalwakurthy Bus Stop', '']
#
# Kalwakurthy Bus Stop
#
# ['478\n', 'Womens college Bus Stop', '']
# 478
#
# Womens college Bus Stop
#
# ['', 'Akulamilaram', '']
#
# Akulamilaram
#
# ['481\n', 'Ibrahimpatnam Bus Station', '']
# 481
#
# Ibrahimpatnam Bus Station
#
# ['', 'Narayanpur', '']
#
# Narayanpur
#
# ['483\n', 'Arutla', '']
# 483
#
# Arutla
#
# ['', 'Chotuppal', '']
#
# Chotuppal
#
# ['486\n', 'Ibrahimpatnam Bus Station', '']
# 486
#
# Ibrahimpatnam Bus Station
#
# ['', 'Madhapur Bus Stop', '']
#
# Madhapur Bus Stop
#
# ['488\n', 'Uppal Bus Stop', '']
# 488
#
# Uppal Bus Stop
#
# ['', 'Bibinagar', '']
#
# Bibinagar
#
# ['491\n', 'Secunderabad Junction', '']
# 491
#
# Secunderabad Junction
#
# ['', 'Bandavirala', '']
#
# Bandavirala
#
# ['493\n', 'Secunderabad Junction', '']
# 493
#
# Secunderabad Junction
#
# ['', 'Jainapally', '']
#
# Jainapally
#
# ['495D\n', 'Kanukunta', '']
# 495D
#
# Kanukunta
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['496\n', 'Secunderabad Junction', '']
# 496
#
# Secunderabad Junction
#
# ['', 'Jiyapally', '']
#
# Jiyapally
#
# ['497\n', 'ECIL Bus Stop', '']
# 497
#
# ECIL Bus Stop
#
# ['', 'Hajipur', '']
#
# Hajipur
#
# ['498\n', 'ECIL Bus Stop', '']
# 498
#
# ECIL Bus Stop
#
# ['', 'Keshavpur', '']
#
# Keshavpur
#
# ['502\n', 'Patancheru Bus Stop', '']
# 502
#
# Patancheru Bus Stop
#
# ['', 'Ordnance Factory', '']
#
# Ordnance Factory
#
# ['506\n', 'Balanagar Bus Stop', '']
# 506
#
# Balanagar Bus Stop
#
# ['', 'Kothapalli', '']
#
# Kothapalli
#
# ['511\n', 'Narsapur', '']
# 511
#
# Narsapur
#
# ['', 'JBS Bus Stop', '']
#
# JBS Bus Stop
#
# ['516\n', 'Patancheru Bus Stop', '']
# 516
#
# Patancheru Bus Stop
#
# ['', 'Ordnance Factory', '']
#
# Ordnance Factory
#
# ['518\n', 'Patancheru Bus Stop', '']
# 518
#
# Patancheru Bus Stop
#
# ['', 'Shankerpally', '']
#
# Shankerpally
#
# ['522\n', 'Ibrahimpatnam Bus Station', '']
# 522
#
# Ibrahimpatnam Bus Station
#
# ['', 'Yadigirigutta APSRTC Bus Stand', '']
#
# Yadigirigutta APSRTC Bus Stand
#
# ['524\n', 'Womens college Bus Stop', '']
# 524
#
# Womens college Bus Stop
#
# ['', 'Ramdaspally', '']
#
# Ramdaspally
#
# ['530\n', 'Afzalgunj Bus Stop', '']
# 530
#
# Afzalgunj Bus Stop
#
# ['', 'Kothapet Bus Stop', '']
#
# Kothapet Bus Stop
#
# ['536\n', 'Afzalgunj Bus Stop', '']
# 536
#
# Afzalgunj Bus Stop
#
# ['', 'Mekaguda', '']
#
# Mekaguda
#
# ['540\n', 'MGBS Bus Stop', '']
# 540
#
# MGBS Bus Stop
#
# ['', 'Saireaddyguda Bus Stop', '']
#
# Saireaddyguda Bus Stop
#
# ['544\n', 'Secunderabad Junction', '']
# 544
#
# Secunderabad Junction
#
# ['', 'Fakeerguda', '']
#
# Fakeerguda
#
# ['546\n', 'ECIL Bus Stop', '']
# 546
#
# ECIL Bus Stop
#
# ['', 'Bhongir Bus Stop', '']
#
# Bhongir Bus Stop
#
# ['567\n', 'Medchal', '']
# 567
#
# Medchal
#
# ['', 'Kondapur Bus Stop', '']
#
# Kondapur Bus Stop
#
# ['570\n', 'Secunderabad Junction', '']
# 570
#
# Secunderabad Junction
#
# ['', 'Narayanpur', '']
#
# Narayanpur
#
# ['572\n', 'Laxmapur', '']
# 572
#
# Laxmapur
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['577\n', 'Dharmaram', '']
# 577
#
# Dharmaram
#
# ['', 'ECIL Bus Stop', '']
#
# ECIL Bus Stop
#
# ['579\n', 'Secunderabad Junction', '']
# 579
#
# Secunderabad Junction
#
# ['', 'Alinagar', '']
#
# Alinagar
#
# ['590\n', 'Secunderabad Junction', '']
# 590
#
# Secunderabad Junction
#
# ['', 'Veldurthi', '']
#
# Veldurthi
#
# ['498V\n', 'Jinnaram', '']
# 498V
#
# Jinnaram
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['499\n', 'Jinnaram', '']
# 499
#
# Jinnaram
#
# ['', 'Secunderabad Junction', '']
#
# Secunderabad Junction
#
# ['503\n', 'Patancheru Bus Stop', '']
# 503
#
# Patancheru Bus Stop
#
# ['', 'Kollur Bus Stop', '']
#
# Kollur Bus Stop
#
# ['509\n', 'Panyal/Konyal', '']
# 509
#
# Panyal/Konyal
#
# ['', 'Balanagar Bus Stop', '']
#
# Balanagar Bus Stop
#
# ['515\n', 'Patancheru Bus Stop', '']
# 515
#
# Patancheru Bus Stop
#
# ['', 'Bonthapally', '']
#
# Bonthapally
#
# ['517\n', 'Patancheru Bus Stop', '']
# 517
#
# Patancheru Bus Stop
#
# ['', 'Bonthapally', '']
#
# Bonthapally
#
# ['520\n', 'Patancheru Bus Stop', '']
# 520
#
# Patancheru Bus Stop
#
# ['', 'Doulatabad', '']
#
# Doulatabad
#
# ['523\n', 'Dilsukhnagar Bus station', '']
# 523
#
# Dilsukhnagar Bus station
#
# ['', 'Ramdaspally', '']
#
# Ramdaspally
#
# ['525\n', 'Shamshabad Bus Stop', '']
# 525
#
# Shamshabad Bus Stop
#
# ['', 'Ibrahimpatnam Bus Station', '']
#
# Ibrahimpatnam Bus Station
#
# ['532\n', 'Charminar Bus Stop', '']
# 532
#
# Charminar Bus Stop
#
# ['', 'J P Durgah', '']
#
# J P Durgah
#
# ['539\n', 'Charminar Bus Stop', '']
# 539
#
# Charminar Bus Stop
#
# ['', 'Yacharam(Nagarjuna Sagar Road)', '']
#
# Yacharam(Nagarjuna Sagar Road)
#
# ['543\n', 'Uppal Bus Stop', '']
# 543
#
# Uppal Bus Stop
#
# ['', 'Pochampally', '']
#
# Pochampally
#
# ['545\n', 'Uppal Bus Stop', '']
# 545
#
# Uppal Bus Stop
#
# ['', 'Pochampally', '']
#
# Pochampally
#
# ['564\n', 'Secunderabad Junction', '']
# 564
#
# Secunderabad Junction
#
# ['', 'Nagireddy Palli', '']
#
# Nagireddy Palli
#
# ['568\n', 'Secunderabad Junction', '']
# 568
#
# Secunderabad Junction
#
# ['', 'Timmapur', '']
#
# Timmapur
#
# ['571\n', 'ECIL Bus Stop', '']
# 571
#
# ECIL Bus Stop
#
# ['', 'Gopalapuram', '']
#
# Gopalapuram
#
# ['573\n', 'Medchal', '']
# 573
#
# Medchal
#
# ['', 'Ghatkesar Bus Stop', '']
#
# Ghatkesar Bus Stop
#
# ['578\n', 'Secunderabad Junction', '']
# 578
#
# Secunderabad Junction
#
# ['', 'Narayanpur', '']
#
# Narayanpur
#
# ['588\n', 'Medchal', '']
# 588
#
# Medchal
#
# ['', 'Narsapur', '']
#
# Narsapur
#
# ['591\n', 'Medchal', '']
# 591
#
# Medchal
#
# ['', 'Sikindlapur', '']
#
# Sikindlapur
#
# ['592\n', 'Medchal', '']
# 592
#
# Medchal
#
# ['', 'Gummadidala', '']
#
# Gummadidala
#
# ['593\n', 'Mehdipatnam Bus Stop', '']
# 593
#
# Mehdipatnam Bus Stop
#
# ['', 'Kandada', '']
#
# Kandada
